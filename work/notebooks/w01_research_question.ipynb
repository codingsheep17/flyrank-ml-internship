# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/codingsheep17/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I'm picking Lane 2, Refresh/Content Opportunity Scoring. In the starter- notebooks, I already saw a Random Forest beat
# a hand written rule at flagging- declining pages (Precision@50 of 0.74 vs 0.24), so I want to dig deeper into what makes a page
# worth prioritizing for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages should the content team review and refresh first, out of hundreds/thousands of pages?
#
# Who acts on it: A content editor or SEO strategist — they pick pages off this list and update/rewrite them.
#
# Cost of a wrong call: If we flag a page that didn't actually need fixing, we waste the reviewer's limited time on a page that was fine. If we miss a page that's genuinely declining, it keeps losing traffic and visibility unnoticed for longer, which costs the client real search visibility and revenue.
#
# Unit of analysis: one page (content_id).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os  #repo cloning to the collab

if not os.path.exists("flyrank-ml-internship"):
    # !git clone https://github.com/codingsheep17/flyrank-ml-internship.git

os.chdir("flyrank-ml-internship")
print(os.getcwd())

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

#loading the paths
import os
for root, dirs, files in os.walk('.'):
    for f in files:
        if f.endswith('.csv'):
            print(os.path.join(root, f))
# Out:
# ./outputs/refresh_queue_sample.csv
# ./data/raw/content_refresh_anonymized.csv

# %%
#loading the csv
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Number1 what % of pages are currently declining
declining_pct = (df["trend_direction"] == "down").mean()
print(f"% of pages currently declining: {declining_pct:.1%}")

# Number2 declining vs stable pages - average impressions comparison
print(df.groupby("trend_direction")["impressions_90d"].mean())

# Number3 from the starter pipeline results (already verified in outputs/model_report.md)
print("Hand-rule Precision@50: 0.240  vs  Random Forest Precision@50: 0.740")
# Out:
# % of pages currently declining: 54.2%
# trend_direction
# down      4919.097466
# flat        20.738715
# new        164.131038
# stable    9213.615230
# up        4716.081130
# Name: impressions_90d, dtype: float64
# Hand-rule Precision@50: 0.240  vs  Random Forest Precision@50: 0.740

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can say: which signals are associated with a page declining or underperforming; which pages look worth reviewing first, based on observed- patterns in the data. This is decision-support — it helps a human prioritize, not- replaces their judgment.
#
# What I cannot say: that fixing a flagged page will definitely cause it to recover- (that would need a real controlled experiment, not just this data). I also cannot- claim to know how Google's actual ranking algorithm works — I only observe- outcomes, not the algorithm's internals.
#
# This is for now.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
